# %%
pip install snscrape
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Using OS library to call CLI commands in Python
os.system("snscrape --jsonl --max-results 100000 --since 2022-02-06 twitter-search '#leap22 until:2022-07-10' ")
# Out:
# {"_type": "snscrape.modules.twitter.Tweet", "url": "https://twitter.com/APP_HRF/status/1545348530038251520", "date": "2022-07-08T10:06:15+00:00", "content": "Introducing our fourth local invited speaker for LEAP 2022. Run, don\u2019t walk to our Events Page to register. Early Bird registrations must close 15/7/22. \nhttps://t.co/djlUyu8rJY #LEAP22 https://t.co/avMkfmkLFw", "renderedContent": "Introducing our fourth local invited speaker for LEAP 2022. Run, don\u2019t walk to our Events Page to register. Early Bird registrations must close 15/7/22. \napp-hrf.com.au/events #LEAP22 https://t.co/avMkfmkLFw", "id": 1545348530038251520, "user": {"_type": "snscrape.modules.twitter.User", "username": "APP_HRF", "id": 793039076207108096, "displayname": "APP_HRF", "description": "Advanced Practicing Podiatrists - High Risk Foot group", "rawDescription": "Advanced Practicing Podiatrists - High Risk Foot group", "descriptionUrls": null, "verified": false, "created": "2016-10-31T10:37:04+00:00", 
# ...

# %%
import pandas as pd

# Reads the json generated from the CLI commands above and creates a pandas dataframe
tweets_df = pd.read_json('text-query-tweets.json', lines=True)

# %%
tweets_df.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/APP_HRF/status/15453485300...
# 1  https://twitter.com/APP_HRF/status/15450141046...
# 2  https://twitter.com/LEAPandInnovate/status/154...
# 3  https://twitter.com/leapawards/status/15447140...
# 4  https://twitter.com/LEAPandInnovate/status/154...
#
#                        date  \
# 0 2022-07-08 10:06:15+00:00
# 1 2022-07-07 11:57:22+00:00
# 2 2022-07-07 07:30:10+00:00
# 3 2022-07-06 16:05:04+00:00
# 4 2022-07-04 11:53:16+00:00
#
#                                              content  \
# 0  Introducing our fourth local invited speaker f...
# 1  Introducing our third local invited speaker fo...
# 2  At #LEAP22, Julian Pistone (Regional Industry ...
# ...

# %%
# Export dataframe into a CSV
tweets_df.to_csv('text-query-tweets.csv', sep=',', index=False)

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10169 entries, 0 to 10168
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _type             10169 non-null  object
#  1   url               10169 non-null  object
#  2   date              10169 non-null  datetime64[ns, UTC]
#  3   content           10169 non-null  object
#  4   renderedContent   10169 non-null  object
#  5   id                10169 non-null  int64
#  6   user              10169 non-null  object
#  7   replyCount        10169 non-null  int64
#  8   retweetCount      10169 non-null  int64
#  9   likeCount         10169 non-null  int64
#  10  quoteCount        10169 non-null  int64
#  11  conversationId    10169 non-null  int64
#  12  lang              10169 non-null  object
#  13  source            10169 non-null  object
#  14  sourceUrl         10169 non-null  object
#  15  sourceLabel       10169 non-null  object
# ...

# %%
tweets_df.describe()
# Out:
#                  id    replyCount  retweetCount     likeCount    quoteCount  \
# count  1.016900e+04  10169.000000  10169.000000  10169.000000  10169.000000
# mean   1.488424e+18      1.759170      4.870685     10.251057      0.237093
# std    4.410690e+15     27.463826     75.141415     85.099544      2.222997
# min    1.477271e+18      0.000000      0.000000      0.000000      0.000000
# 25%    1.488140e+18      0.000000      0.000000      0.000000      0.000000
# 50%    1.488587e+18      0.000000      0.000000      1.000000      0.000000
# 75%    1.489161e+18      1.000000      2.000000      5.000000      0.000000
# max    1.545349e+18   2586.000000   6979.000000   7034.000000    113.000000
#
#        conversationId  retweetedTweet  inReplyToTweetId
# count    1.016900e+04             0.0      9.390000e+02
# mean     1.488356e+18             NaN      1.489216e+18
# std      5.441423e+15             NaN      4.893931e+15
# min      1.204118e+18             NaN      1.449674e+18
# ...

# %%
tweets_df.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/APP_HRF/status/15453485300...
# 1  https://twitter.com/APP_HRF/status/15450141046...
# 2  https://twitter.com/LEAPandInnovate/status/154...
# 3  https://twitter.com/leapawards/status/15447140...
# 4  https://twitter.com/LEAPandInnovate/status/154...
#
#                        date  \
# 0 2022-07-08 10:06:15+00:00
# 1 2022-07-07 11:57:22+00:00
# 2 2022-07-07 07:30:10+00:00
# 3 2022-07-06 16:05:04+00:00
# 4 2022-07-04 11:53:16+00:00
#
#                                              content  \
# 0  Introducing our fourth local invited speaker f...
# 1  Introducing our third local invited speaker fo...
# 2  At #LEAP22, Julian Pistone (Regional Industry ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


c=tweets_df[['url','date','content', 'renderedContent', 'id', 'user','replyCount','retweetCount','likeCount',
             'quoteCount','conversationId','lang','source','sourceUrl','sourceLabel','outlinks','tcooutlinks'
            ,'media','retweetedTweet','quotedTweet','inReplyToTweetId','inReplyToUser','mentionedUsers'
            ,'coordinates','place','hashtags','cashtags']]
c
sns.heatmap(c.corr(), annot=True ,cmap=  "Reds")
plt.show()
